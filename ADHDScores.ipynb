# %%
import csv
import time
import numpy as np
import pandas as pd

# %%
def createDataSet():
    #

# %%
def extractQuestions():
    # file = open("ADHDSelfReported.csv", "w", encoding="utf8")
    # f = csv.writer(file)
    df = pd.read_csv("sassema baseline 3.16.2023.csv")
    # de = pd.read_csv("ADHDSelfReported.csv")

    # question = df["ADHDSx_"+ str(18)]
    
    # for x in range(1,19):
    #     print(x)

    # question.to_csv("ADHDSelfReported.csv", index=False)
    # all = []

    de = df[["ADHDSx_1","ADHDSx_2","ADHDSx_3","ADHDSx_4","ADHDSx_5","ADHDSx_6","ADHDSx_7","ADHDSx_8","ADHDSx_9","ADHDSx_10","ADHDSx_11","ADHDSx_12","ADHDSx_13","ADHDSx_14","ADHDSx_15","ADHDSx_16","ADHDSx_17","ADHDSx_18"]].copy()
    
    # for i in range(1,19):
        # f.writerow(['question1'])
        # all.append(question)
        # de["ADHDSx_"+ str(i)] = question
        # print(de["ADHDSx_"+ str(i)])
        # question.to_csv("ADHDSelfReported.csv", mode ='a',index=False)
    # for word in all:
    #     f.writerow([word])
    # f.writerow(all)
    de.to_csv("ADHDSelfReported.csv", index=False)

# %%
extractQuestions()
df = pd.read_csv("ADHDSelfReported.csv")
df
# Out:
#                                              ADHDSx_1  \
# 0   Fail to give close attention to details or mak...
# 1                               {"ImportId":"QID106"}
# 2                                           Sometimes
# 3                                          Very often
# 4                                               Often
# 5                                     Never or rarely
# 6                                     Never or rarely
# 7                                           Sometimes
# 8                                     Never or rarely
# 9                                     Never or rarely
# 10                                         Very often
# 11                                          Sometimes
# 12                                         Very often
# 13                                          Sometimes
# 14                                          Sometimes
# 15                                                NaN
# ...
