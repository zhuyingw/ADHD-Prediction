# %%
# starter code 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(40)

df=pd.read_csv("upscaling.csv")    #read file.
X1=df[['Still Morning', 'Still Afternoon', 'Still Evening', 'Still Night', 'Running Morning', 'Running Afternoon', 'Running Evening', 'Running Night']]

#Checking if the dataframe contains empty cell values.
#df.isnull().values.any())    

#Output label
y=df['ADHD']

#Plot features and label in feature visual file

from sklearn.preprocessing import MinMaxScaler

#Normalize features using MinMaxScaler.
#Please see https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html for more details.
scaler = MinMaxScaler()
scaler.fit(X1)
X1 = scaler.transform(X1)

#Normalize features using MinMaxScaler.
#Please see https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html for more details.

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import f1_score

X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size = 0.30, 
random_state= 42)

# authroized_or_not = (y == 0) | (y == 1)
# X = X_train[authroized_or_not]
# y = y_train[authroized_or_not]


# SVM Classifier model
C = [1,10,100,1000]
y_predict = []
for x in C:
    print("When C is ", x)
    print("======================")
    print("======================")

    name = "Linear Kernel"
    print(name)
    print("=======================")
    svm_clf = SVC(kernel="linear", C=x) #using C=1
    # svm_clf.fit(X, y)
    # #predict on test data
    # #providing test data for petal length and width and testing the model.
    #Actual label is 0.
    svm_clf.fit(X_train,y_train)

    tmp = svm_clf.score(X_test,y_test)
    print("The Linear kernal returns: ", tmp)
    
    y_predict = svm_clf.predict(X_test)
    confusion_matrix = metrics.confusion_matrix(y_predict,y_test)
    print(name, "Confusion Matrix: ")
    print(confusion_matrix)
    F1 = f1_score(y_predict,y_test)
    print(name, "F1: ", F1)
    tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_predict).ravel()
    print(tn, fp, fn, tp)
    print(name, "precision is: ", tp/(tp+fp))
    print(name, "recall is: ", tp/(tp+fn))
    print(name, "accuracy is: ", (tp+tn)/(tp+tn+fp+fn))
    print("-----------------------")

    name = "Poly Kernel"
    print(name)
    print("=======================")

    svm_clf = SVC(kernel='poly', degree=2,C=x) #polynomial kernel with degree 2.
    svm_clf.fit(X_train,y_train)

    tmp = svm_clf.score(X_test,y_test)
    print("The Poly kernal returns: ", tmp)

        
    y_predict = svm_clf.predict(X_test)
    confusion_matrix = metrics.confusion_matrix(y_predict,y_test)
    print(name, "Confusion Matrix: ")
    print(confusion_matrix)
    F1 = f1_score(y_predict,y_test)
    print(name, "F1: ", F1)
    tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_predict).ravel()
    print(tn, fp, fn, tp)
    print(name, "precision is: ", tp/(tp+fp))
    print(name, "recall is: ", tp/(tp+fn))
    print(name, "accuracy is: ", (tp+tn)/(tp+tn+fp+fn))
    print("-----------------------")

    name = "RBF Kernel"
    print(name)
    print("=======================")
    
    svm_clf = SVC(kernel='rbf', gamma=1,C=x) #gaussian rbf kernel.
    svm_clf.fit(X_train,y_train)
    
    tmp = svm_clf.score(X_test,y_test)
    print("The RBF kernal returns: ", tmp)

    y_predict = svm_clf.predict(X_test)
    confusion_matrix = metrics.confusion_matrix(y_predict,y_test)
    print(name, "Confusion Matrix: ")
    print(confusion_matrix)
    F1 = f1_score(y_predict,y_test)
    print(name, "F1: ", F1)
    tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_predict).ravel()
    print(tn, fp, fn, tp)
    print(name, "precision is: ", tp/(tp+fp))
    print(name, "recall is: ", tp/(tp+fn))
    print(name, "accuracy is: ", (tp+tn)/(tp+tn+fp+fn))
    print("-----------------------")

    


# print("The average prediction value is",round(scores.mean(),3))
# Out:
# When C is  1
# ======================
# ======================
# Linear Kernel
# =======================
# The Linear kernal returns:  0.8181818181818182
# Linear Kernel Confusion Matrix:
# [[10  2]
#  [ 4 17]]
# Linear Kernel F1:  0.8500000000000001
# 10 4 2 17
# Linear Kernel precision is:  0.8095238095238095
# Linear Kernel recall is:  0.8947368421052632
# Linear Kernel accuracy is:  0.8181818181818182
# -----------------------
# Poly Kernel
# =======================
# The Poly kernal returns:  0.7575757575757576
# Poly Kernel Confusion Matrix:
# [[10  4]
#  [ 4 15]]
# Poly Kernel F1:  0.7894736842105263
# 10 4 4 15
# Poly Kernel precision is:  0.7894736842105263
# Poly Kernel recall is:  0.7894736842105263
# Poly Kernel accuracy is:  0.7575757575757576
# -----------------------
# RBF Kernel
# =======================
# The RBF kernal returns:  0.7575757575757576
# RBF Kernel Confusion Matrix:
# [[10  4]
#  [ 4 15]]
# RBF Kernel F1:  0.7894736842105263
# 10 4 4 15
# RBF Kernel precision is:  0.7894736842105263
# RBF Kernel recall is:  0.7894736842105263
# RBF Kernel accuracy is:  0.7575757575757576
# -----------------------
# When C is  10
# ======================
# ======================
# Linear Kernel
# =======================
# The Linear kernal returns:  0.7575757575757576
# Linear Kernel Confusion Matrix:
# [[10  4]
#  [ 4 15]]
# Linear Kernel F1:  0.7894736842105263
# 10 4 4 15
# Linear Kernel precision is:  0.7894736842105263
# Linear Kernel recall is:  0.7894736842105263
# Linear Kernel accuracy is:  0.7575757575757576
# -----------------------
# Poly Kernel
# =======================
# The Poly kernal returns:  0.7878787878787878
# Poly Kernel Confusion Matrix:
# [[11  4]
#  [ 3 15]]
# Poly Kernel F1:  0.8108108108108109
# 11 3 4 15
# Poly Kernel precision is:  0.8333333333333334
# Poly Kernel recall is:  0.7894736842105263
# Poly Kernel accuracy is:  0.7878787878787878
# -----------------------
# RBF Kernel
# =======================
# The RBF kernal returns:  0.8181818181818182
# RBF Kernel Confusion Matrix:
# [[11  3]
#  [ 3 16]]
# RBF Kernel F1:  0.8421052631578947
# 11 3 3 16
# RBF Kernel precision is:  0.8421052631578947
# RBF Kernel recall is:  0.8421052631578947
# RBF Kernel accuracy is:  0.8181818181818182
# -----------------------
# When C is  100
# ======================
# ======================
# Linear Kernel
# =======================
# The Linear kernal returns:  0.7575757575757576
# Linear Kernel Confusion Matrix:
# [[10  4]
#  [ 4 15]]
# Linear Kernel F1:  0.7894736842105263
# 10 4 4 15
# Linear Kernel precision is:  0.7894736842105263
# Linear Kernel recall is:  0.7894736842105263
# Linear Kernel accuracy is:  0.7575757575757576
# -----------------------
# Poly Kernel
# =======================
# The Poly kernal returns:  0.8181818181818182
# Poly Kernel Confusion Matrix:
# [[11  3]
#  [ 3 16]]
# Poly Kernel F1:  0.8421052631578947
# 11 3 3 16
# Poly Kernel precision is:  0.8421052631578947
# Poly Kernel recall is:  0.8421052631578947
# Poly Kernel accuracy is:  0.8181818181818182
# -----------------------
# RBF Kernel
# =======================
# The RBF kernal returns:  0.8484848484848485
# RBF Kernel Confusion Matrix:
# [[12  3]
#  [ 2 16]]
# RBF Kernel F1:  0.8648648648648649
# 12 2 3 16
# RBF Kernel precision is:  0.8888888888888888
# RBF Kernel recall is:  0.8421052631578947
# RBF Kernel accuracy is:  0.8484848484848485
# -----------------------
# When C is  1000
# ======================
# ======================
# Linear Kernel
# =======================
# The Linear kernal returns:  0.7575757575757576
# Linear Kernel Confusion Matrix:
# [[10  4]
#  [ 4 15]]
# Linear Kernel F1:  0.7894736842105263
# 10 4 4 15
# Linear Kernel precision is:  0.7894736842105263
# Linear Kernel recall is:  0.7894736842105263
# Linear Kernel accuracy is:  0.7575757575757576
# -----------------------
# Poly Kernel
# =======================
# The Poly kernal returns:  0.7878787878787878
# Poly Kernel Confusion Matrix:
# [[11  4]
#  [ 3 15]]
# Poly Kernel F1:  0.8108108108108109
# 11 3 4 15
# Poly Kernel precision is:  0.8333333333333334
# Poly Kernel recall is:  0.7894736842105263
# Poly Kernel accuracy is:  0.7878787878787878
# -----------------------
# RBF Kernel
# =======================
# The RBF kernal returns:  0.8484848484848485
# RBF Kernel Confusion Matrix:
# [[12  3]
#  [ 2 16]]
# RBF Kernel F1:  0.8648648648648649
# 12 2 3 16
# RBF Kernel precision is:  0.8888888888888888
# RBF Kernel recall is:  0.8421052631578947
# RBF Kernel accuracy is:  0.8484848484848485
# -----------------------

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost
from xgboost import XGBClassifier
from sklearn import metrics
from sklearn.metrics import f1_score
#repeate for decision tree, random forest, XGBoost

name = "Decision Tree"
print("=======================")
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train,y_train)
tmp = clf.score(X_test,y_test)
print("Decision Tree returns: ", tmp)
y_predict = clf.predict(X_test)
confusion_matrix = metrics.confusion_matrix(y_predict,y_test)
print("Decision Tree Confusion Matrix: ")
print(confusion_matrix)
F1 = f1_score(y_predict,y_test)
print("Decision Tree F1: ", F1)
tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_predict).ravel()
print(tn, fp, fn, tp)
print(name, "precision is: ", tp/(tp+fp))
print(name, "recall is: ", tp/(tp+fn))
print(name, "accuracy is: ", (tp+tn)/(tp+tn+fp+fn))




name = "Random Forest"
print("=======================")
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train,y_train)
tmp = clf.score(X_test,y_test)
print("Random Forest returns: ", tmp)

y_predict = clf.predict(X_test)
confusion_matrix = metrics.confusion_matrix(y_predict,y_test)
print(name, "Confusion Matrix: ")
print(confusion_matrix)
F1 = f1_score(y_predict,y_test)
print(name, "F1: ", F1)
tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_predict).ravel()
print(tn, fp, fn, tp)
print(name, "precision is: ", tp/(tp+fp))
print(name, "recall is: ", tp/(tp+fn))
print(name, "accuracy is: ", (tp+tn)/(tp+tn+fp+fn))




name = "XGBoost"
print("=======================")
clf = XGBClassifier()
clf.fit(X_train,y_train)
tmp = tmp = clf.score(X_test,y_test)
print("XGBoost returns: ", tmp)


y_predict = clf.predict(X_test)
confusion_matrix = metrics.confusion_matrix(y_predict,y_test)
print(name, "Confusion Matrix: ")
print(confusion_matrix)
F1 = f1_score(y_predict,y_test)
print(name, "F1: ", F1)
tn, fp, fn, tp = metrics.confusion_matrix(y_test, y_predict).ravel()
print(tn, fp, fn, tp)
print(name, "precision is: ", tp/(tp+fp))
print(name, "recall is: ", tp/(tp+fn))
print(name, "accuracy is: ", (tp+tn)/(tp+tn+fp+fn))
# Out:
# =======================
# Decision Tree returns:  0.7272727272727273
# Decision Tree Confusion Matrix:
# [[10  5]
#  [ 4 14]]
# Decision Tree F1:  0.7567567567567567
# 10 4 5 14
# Decision Tree precision is:  0.7777777777777778
# Decision Tree recall is:  0.7368421052631579
# Decision Tree accuracy is:  0.7272727272727273
# =======================
# Random Forest returns:  0.8484848484848485
# Random Forest Confusion Matrix:
# [[12  3]
#  [ 2 16]]
# Random Forest F1:  0.8648648648648649
# 12 2 3 16
# Random Forest precision is:  0.8888888888888888
# Random Forest recall is:  0.8421052631578947
# Random Forest accuracy is:  0.8484848484848485
# =======================
# XGBoost returns:  0.8484848484848485
# XGBoost Confusion Matrix:
# [[12  3]
#  [ 2 16]]
# XGBoost F1:  0.8648648648648649
# 12 2 3 16
# XGBoost precision is:  0.8888888888888888
# XGBoost recall is:  0.8421052631578947
# XGBoost accuracy is:  0.8484848484848485

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import BinaryCrossentropy

tf.random.set_seed(40)

model = Sequential([
    Dense(units=5, activation="relu",input_shape=(8,)),
    Dense(units=3, activation="relu"),
    Dense(units=1, activation="sigmoid")])
model.compile(loss='binary_crossentropy',optimizer = 'adam',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=100)
predicted = (model.predict(X_test) > 0.5).astype("int32")

# Accuracy 
Accuracy = metrics.accuracy_score(y_test, predicted)
print("Accuracy for NN:",Accuracy)

# Precision
Precision = metrics.precision_score(y_test, predicted)
print("Precision for NN:",Precision)

# Recall
Recall = metrics.recall_score(y_test, predicted)
print("Recall for NN:",Recall)

# F1 score
F1_score = metrics.f1_score(y_test, predicted)
print("F1 score for NN:",F1_score)
print()
# Out:
# Epoch 1/100
# 2023-04-14 15:11:56.854180: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3/3 [==============================] - 1s 2ms/step - loss: 0.6495 - accuracy: 0.6486
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6467 - accuracy: 0.6622
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6444 - accuracy: 0.7027
# Epoch 4/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6419 - accuracy: 0.7027
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6399 - accuracy: 0.7027
# Epoch 6/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6382 - accuracy: 0.6757
# Epoch 7/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6364 - accuracy: 0.6757
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6351 - accuracy: 0.6757
# Epoch 9/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6335 - accuracy: 0.6622
# Epoch 10/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6321 - accuracy: 0.6622
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6307 - accuracy: 0.6622
# Epoch 12/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6296 - accuracy: 0.6622
# Epoch 13/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6279 - accuracy: 0.6622
# Epoch 14/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6263 - accuracy: 0.6622
# Epoch 15/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6248 - accuracy: 0.6757
# Epoch 16/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6231 - accuracy: 0.6757
# Epoch 17/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6215 - accuracy: 0.6757
# Epoch 18/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6201 - accuracy: 0.6757
# Epoch 19/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6185 - accuracy: 0.6757
# Epoch 20/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6168 - accuracy: 0.6757
# Epoch 21/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6154 - accuracy: 0.6892
# Epoch 22/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6138 - accuracy: 0.6892
# Epoch 23/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6119 - accuracy: 0.7027
# Epoch 24/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6101 - accuracy: 0.7297
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6082 - accuracy: 0.7297
# Epoch 26/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6062 - accuracy: 0.7297
# Epoch 27/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.7297
# Epoch 28/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6022 - accuracy: 0.7432
# Epoch 29/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6002 - accuracy: 0.7568
# Epoch 30/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5980 - accuracy: 0.7703
# Epoch 31/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5959 - accuracy: 0.7838
# Epoch 32/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5937 - accuracy: 0.7973
# Epoch 33/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5917 - accuracy: 0.7973
# Epoch 34/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5902 - accuracy: 0.7973
# Epoch 35/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5880 - accuracy: 0.7973
# Epoch 36/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5862 - accuracy: 0.7973
# Epoch 37/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5843 - accuracy: 0.7973
# Epoch 38/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.7703
# Epoch 39/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5808 - accuracy: 0.7703
# Epoch 40/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5790 - accuracy: 0.7973
# Epoch 41/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.7973
# Epoch 42/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5753 - accuracy: 0.7973
# Epoch 43/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5735 - accuracy: 0.7838
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5717 - accuracy: 0.7973
# Epoch 45/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5699 - accuracy: 0.7973
# Epoch 46/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5681 - accuracy: 0.7973
# Epoch 47/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.7973
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.7973
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5631 - accuracy: 0.7973
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5613 - accuracy: 0.7973
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5595 - accuracy: 0.7973
# Epoch 52/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5575 - accuracy: 0.7973
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5557 - accuracy: 0.7973
# Epoch 54/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5542 - accuracy: 0.7973
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5531 - accuracy: 0.8108
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5509 - accuracy: 0.8108
# Epoch 57/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5490 - accuracy: 0.8108
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5471 - accuracy: 0.8108
# Epoch 59/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5455 - accuracy: 0.8108
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.8108
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5421 - accuracy: 0.8108
# Epoch 62/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5405 - accuracy: 0.8108
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5390 - accuracy: 0.8108
# Epoch 64/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5374 - accuracy: 0.8108
# Epoch 65/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5356 - accuracy: 0.8108
# Epoch 66/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5340 - accuracy: 0.8108
# Epoch 67/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5324 - accuracy: 0.8108
# Epoch 68/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5310 - accuracy: 0.8108
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.8108
# Epoch 70/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5273 - accuracy: 0.8108
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5259 - accuracy: 0.8108
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5247 - accuracy: 0.8108
# Epoch 73/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.8108
# Epoch 74/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5214 - accuracy: 0.8108
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5196 - accuracy: 0.8108
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5180 - accuracy: 0.8108
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.8108
# Epoch 78/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5144 - accuracy: 0.8108
# Epoch 79/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5126 - accuracy: 0.8108
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5110 - accuracy: 0.8108
# Epoch 81/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5094 - accuracy: 0.8108
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5079 - accuracy: 0.8108
# Epoch 83/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5065 - accuracy: 0.8108
# Epoch 84/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5047 - accuracy: 0.8243
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.8108
# Epoch 86/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5017 - accuracy: 0.8108
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.8108
# Epoch 88/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4987 - accuracy: 0.8378
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4969 - accuracy: 0.8378
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4955 - accuracy: 0.8378
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4938 - accuracy: 0.8378
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4923 - accuracy: 0.8378
# Epoch 93/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4906 - accuracy: 0.8378
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4893 - accuracy: 0.8378
# Epoch 95/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4876 - accuracy: 0.8378
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4863 - accuracy: 0.8378
# Epoch 97/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4849 - accuracy: 0.8378
# Epoch 98/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4833 - accuracy: 0.8378
# Epoch 99/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4821 - accuracy: 0.8378
# Epoch 100/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.8378
# 2/2 [==============================] - 0s 2ms/step
# Accuracy for NN: 0.8181818181818182
# Precision for NN: 0.8421052631578947
# Recall for NN: 0.8421052631578947
# F1 score for NN: 0.8421052631578947

# %%
model = Sequential([
    Dense(units=4, activation="relu",input_shape=(8,)),
    Dense(units=1, activation="sigmoid")])
model.compile(loss='binary_crossentropy',optimizer = 'adam',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=100)
predicted = (model.predict(X_test) > 0.5).astype("int32")

# Accuracy 
Accuracy = metrics.accuracy_score(y_test, predicted)
print("Accuracy for NN:",Accuracy)

# Precision
Precision = metrics.precision_score(y_test, predicted)
print("Precision for NN:",Precision)

# Recall
Recall = metrics.recall_score(y_test, predicted)
print("Recall for NN:",Recall)

# F1 score
F1_score = metrics.f1_score(y_test, predicted)
print("F1 score for NN:",F1_score)
print()
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7177 - accuracy: 0.4865
# Epoch 2/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7163 - accuracy: 0.5135
# Epoch 3/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7151 - accuracy: 0.4595
# Epoch 4/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7139 - accuracy: 0.4324
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7126 - accuracy: 0.4189
# Epoch 6/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7113 - accuracy: 0.4054
# Epoch 7/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7099 - accuracy: 0.4054
# Epoch 8/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7089 - accuracy: 0.4054
# Epoch 9/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7077 - accuracy: 0.4054
# Epoch 10/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7067 - accuracy: 0.3919
# Epoch 11/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7056 - accuracy: 0.3784
# Epoch 12/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7049 - accuracy: 0.3784
# Epoch 13/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7038 - accuracy: 0.4054
# Epoch 14/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7031 - accuracy: 0.4054
# Epoch 15/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7022 - accuracy: 0.4054
# Epoch 16/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7014 - accuracy: 0.4189
# Epoch 17/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7007 - accuracy: 0.4459
# Epoch 18/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6998 - accuracy: 0.4189
# Epoch 19/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6992 - accuracy: 0.4054
# Epoch 20/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6984 - accuracy: 0.4189
# Epoch 21/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6977 - accuracy: 0.4189
# Epoch 22/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6970 - accuracy: 0.4189
# Epoch 23/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6964 - accuracy: 0.4189
# Epoch 24/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6956 - accuracy: 0.4324
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6950 - accuracy: 0.4054
# Epoch 26/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6944 - accuracy: 0.4189
# Epoch 27/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.4189
# Epoch 28/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.4459
# Epoch 29/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.4730
# Epoch 30/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.4865
# Epoch 31/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6920 - accuracy: 0.4865
# Epoch 32/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6917 - accuracy: 0.4865
# Epoch 33/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6915 - accuracy: 0.4865
# Epoch 34/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.4865
# Epoch 35/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6911 - accuracy: 0.4865
# Epoch 36/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.4865
# Epoch 37/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.4865
# Epoch 38/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6904 - accuracy: 0.4865
# Epoch 39/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6902 - accuracy: 0.5270
# Epoch 40/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6899 - accuracy: 0.5270
# Epoch 41/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6898 - accuracy: 0.5405
# Epoch 42/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5405
# Epoch 43/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.5405
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5405
# Epoch 45/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.5405
# Epoch 46/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6890 - accuracy: 0.5405
# Epoch 47/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.5405
# Epoch 48/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.5676
# Epoch 49/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.5676
# Epoch 50/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6885 - accuracy: 0.5676
# Epoch 51/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.5676
# Epoch 52/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.5405
# Epoch 53/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5135
# Epoch 54/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6881 - accuracy: 0.5135
# Epoch 55/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6881 - accuracy: 0.5135
# Epoch 56/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6879 - accuracy: 0.5135
# Epoch 57/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6879 - accuracy: 0.5135
# Epoch 58/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.5135
# Epoch 59/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.5135
# Epoch 60/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6877 - accuracy: 0.5135
# Epoch 61/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.5135
# Epoch 62/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6875 - accuracy: 0.5135
# Epoch 63/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6874 - accuracy: 0.5135
# Epoch 64/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6874 - accuracy: 0.5135
# Epoch 65/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6873 - accuracy: 0.5270
# Epoch 66/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5270
# Epoch 67/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.5270
# Epoch 68/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6871 - accuracy: 0.5541
# Epoch 69/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6870 - accuracy: 0.5541
# Epoch 70/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.5541
# Epoch 71/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.5676
# Epoch 72/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.5811
# Epoch 73/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.5811
# Epoch 74/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.5811
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.5811
# Epoch 76/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5676
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5541
# Epoch 78/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5541
# Epoch 79/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5541
# Epoch 80/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.5541
# Epoch 81/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.5541
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5541
# Epoch 83/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.5541
# Epoch 84/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5811
# Epoch 85/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5811
# Epoch 86/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.5811
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5811
# Epoch 88/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5811
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5811
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.5541
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6853 - accuracy: 0.5811
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5811
# Epoch 93/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6852 - accuracy: 0.5811
# Epoch 94/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5811
# Epoch 95/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5541
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5541
# Epoch 97/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.5135
# Epoch 98/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5135
# Epoch 99/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5135
# Epoch 100/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5135
# 2/2 [==============================] - 0s 2ms/step
# Accuracy for NN: 0.5757575757575758
# Precision for NN: 0.5757575757575758
# Recall for NN: 1.0
# F1 score for NN: 0.7307692307692308
